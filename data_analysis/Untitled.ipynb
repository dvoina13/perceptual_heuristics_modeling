# %%
import numpy as np
import scipy.io as sio
import os
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
from scipy.stats import wilcoxon
from scipy.stats import mannwhitneyu
import random
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LinearRegression
from scipy.stats import norm
from sklearn import svm
from scipy.linalg import solve

import torch
import torch.nn as nn
import torch.optim as optim

# %%
seed = 1
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.use_deterministic_algorithms(True)

# %%
df_sessions_m1_phase1 = {}

directory = 'new_pooya_data/M1_phase1_Lf/'
sess_folder = os.listdir(directory)
sess_folder
# Out:
# ['Session7',
#  'Session4',
#  'Session3',
#  'Session9',
#  'Session1',
#  'Session6',
#  'Session10',
#  'Session8',
#  'Session2',
#  'Session5']

# %%
for sess in sess_folder:
    print("sess", sess)
    files = os.listdir(directory + sess)
    print("files", files)
    for file in files:
        mat_contents = sio.loadmat(directory + sess +"/"+file)
        print("file", file)
# Out:
# sess Session7
# files ['spikes_sig21.mat', 'spikes_sig15.mat', 'spikes_sig20.mat', 'spikes_sig09.mat', 'spikes_sig18.mat', 'spikes_sig11.mat', 'spikes_sig24.mat', 'spikes_sig23.mat', '.DS_Store', 'spikes_sig10.mat', 'spikes_sig19.mat']
# file spikes_sig21.mat
# file spikes_sig15.mat
# file spikes_sig20.mat
# file spikes_sig09.mat
# file spikes_sig18.mat
# file spikes_sig11.mat
# file spikes_sig24.mat
# file spikes_sig23.mat
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[24], line 6
#       4 print("files", files)
#       5 for file in files:
# ----> 6     mat_contents = sio.loadmat(directory + sess +"/"+file)
#       7     print("file", file)
#
# File ~/anaconda3/envs/lightly_env/lib/python3.11/site-packages/scipy/io/matlab/_mio.py:235, in loadmat(file_name, mdict, appendmat, spmatrix, **kwargs)
#     233 with _open_file_context(file_name, appendmat) as f:
# ...

# %%
mat_contents["spikes"][0]
# Out:
# array([(array([[(array([[30000]], dtype=uint16), array(['auto'], dtype='<U4'), array([[2.8]]), array([[1.5]]), array([[0.75]]), array([[0.6]]), array([[2.5]]), array([[0.6]]), array([[0.05]]), array([[500]], dtype=uint16), array([[(array([[3]], dtype=uint8), array([[1]], dtype=uint8), array([[0.04166667, 0.        , 0.        ],
#                               [0.08333333, 0.        , 0.        ],
#                               [0.125     , 0.        , 0.        ],
#                               [0.16666667, 0.        , 0.        ],
#                               [0.20833333, 0.        , 0.        ],
#                               [0.25      , 0.        , 0.        ],
#                               [0.29166667, 0.        , 0.        ],
#                               [0.33333333, 0.        , 0.        ],
#                               [0.375     , 0.        , 0.        ],
#                               [0.41666667, 0.        , 0.        ],
# ...

# %%
mat_contents["spikes"]["spiketimes"]
# Out:
# array([[array([[5.5128238e-03, 4.0865149e-02, 5.4626383e-02, ..., 1.7149038e+03,
#                 1.7149073e+03, 1.7149160e+03]], dtype=float32)                  ]],
#       dtype=object)

# %%
mat_contents["spikes"]['spiketimes'][0][0][0]
# Out:
# array([5.5128238e-03, 4.0865149e-02, 5.4626383e-02, ..., 1.7149038e+03,
#        1.7149073e+03, 1.7149160e+03], dtype=float32)

# %%
mat_contents["spikes"]['spiketimes'][0, 0].squeeze()
# Out:
# array([5.5128238e-03, 4.0865149e-02, 5.4626383e-02, ..., 1.7149038e+03,
#        1.7149073e+03, 1.7149160e+03], dtype=float32)
